# %%
from google.colab import drive
drive.mount('/content/drive')
#
# %cd "/content/drive/MyDrive/IA/2doparcial/IA/EtregableImg"
# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/IA/2doparcial/IA/EtregableImg
#  Examples  'Loaded pokemon.ipynb'   poke.h5   pokemon   Pokemon   pokemon.ipynb

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.models import load_model
import numpy as np
import os

# %% [markdown]
# Agregamos las etiquetas para la clasificacion del modelo
#
# Como dato curioso, esto era lo que hacía que mi modelo no corriera, porque se me olvidaba que los diccionarios son ordenados y tenía que poner mis clases en orden alfabetico xd

# %%
# Etiquetas de cada clase corresponidente a los índices
labels = {
    0: 'bulbasaur',
    1: 'charmander',
    2: 'pikachu',
    3: 'squirtle',
}

# %%
# Carga del modelo
model = load_model('poke.h5')

# %% [markdown]
# La demostración de predicciones se realizó a través de un conjunto de imágenes de ejemplo obtenidas de internet.
#
# Este conjunto se encuentra en la carpeta Examples, separadas por cada clase para poder comparar su predicción con la clase original.

# %%
# Cargado de imagenes y guardado de predicciones
prediction = []
original = []
image = []
count = 0
examples_path = 'Examples'

# Recorre los tipos de ejemplos
for i in os.listdir(examples_path):
    # Recorre los elementos dentro de cada conjunto
    for item in os.listdir(os.path.join(examples_path, i)):
        # Carga de la imagen
        img = tf.keras.utils.load_img(os.path.join(examples_path, i, item), target_size=(200, 200))
        # Se guarda la imagen en un arreglo
        image.append(img)
        # Se realizan transformaciones a la imagen para que pueda ser utilizada
        img = np.array(img)
        ##img = img / 255.0
        # Se especifican las dimensiones
        img = img.reshape(1,200,200,3)
        # Predicción del modelo
        predict = model.predict(img)
        # Se obtiene el índice del valor más grande en la predicción
        predict = np.argmax(predict)
        # Se guarda el valor de ese índice en un arreglo
        prediction.append(labels[predict])
        # Se guarda la clase original para su comprobación
        original.append(i)
# Out:
# 1/1 [==============================] - 1s 537ms/step
# 1/1 [==============================] - 0s 376ms/step
# 1/1 [==============================] - 0s 387ms/step
# 1/1 [==============================] - 0s 380ms/step
# 1/1 [==============================] - 0s 407ms/step
# 1/1 [==============================] - 0s 463ms/step
# 1/1 [==============================] - 1s 720ms/step
# 1/1 [==============================] - 1s 713ms/step
# 1/1 [==============================] - 1s 723ms/step
# 1/1 [==============================] - 1s 717ms/step
# 1/1 [==============================] - 1s 723ms/step
# 1/1 [==============================] - 0s 381ms/step
# 1/1 [==============================] - 0s 381ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 375ms/step
# 1/1 [==============================] - 0s 388ms/step
# 1/1 [==============================] - 0s 381ms/step
# 1/1 [==============================] - 0s 393ms/step
# 1/1 [==============================] - 0s 391ms/step
# 1/1 [==============================] - 0s 382ms/step
# 1/1 [==============================] - 0s 389ms/step
# 1/1 [==============================] - 0s 378ms/step
# 1/1 [==============================] - 0s 377ms/step
# 1/1 [==============================] - 0s 377ms/step

# %%
# Arreglo con numero de elementos predichos
n = []
for i in range(len(image)):
    n.append(i)

# %%
# Visualización de los resultados
fig = plt.figure(figsize = (100,100))

for i in range(len(n)):
    fig.add_subplot(30,1,i+1)
    plt.xlabel("Prediction -" + prediction[i] +"   Original -" + original[i])
    plt.imshow(image[i])
fig.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# EN CONCLUSIÓN
#
# se puede decir que el modelo predice perfectamente, inclsuive imagenes con ruido como el squirtle soldado con gorrito, lo que quiere decir qeu el modelo esta correctamente bien entrenado.
#
# Como futuras actualizaciones fuera de la materia, quisiera que este modelo sea para los 150 pokemons y que pueda predecir no solamente lo que es el pokemon, sino tambien el tipo.
